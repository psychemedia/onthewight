# %%
#You may need to install beautifulsoup
#!pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.iwight.com/planning/planAppSearch.aspx'
response =requests.get(url)

# %%
soup=BeautifulSoup(response.content)
viewstate = soup.find('input' , id ='__VIEWSTATE')['value']
eventvalidation=soup.find('input' , id ='__EVENTVALIDATION')['value']
viewstategenerator=soup.find('input' , id ='__VIEWSTATEGENERATOR')['value']

# %%
params={'__EVENTTARGET':'lnkShowAll','__EVENTARGUMENT':'','__VIEWSTATE':viewstate,
        '__VIEWSTATEGENERATOR':viewstategenerator,
        '__EVENTVALIDATION':eventvalidation,'q':'Search the site...'}

# %%
r=requests.post(url,data=params)

# %%
from math import sqrt, pi, sin, cos, tan, atan2 as arctan2

#http://www.hannahfry.co.uk/blog/2012/02/01/converting-british-national-grid-to-latitude-and-longitude-ii
def OSGB36toWGS84(E,N):

    #E, N are the British national grid coordinates - eastings and northings
    a, b = 6377563.396, 6356256.909     #The Airy 180 semi-major and semi-minor axes used for OSGB36 (m)
    F0 = 0.9996012717                   #scale factor on the central meridian
    lat0 = 49*pi/180                    #Latitude of true origin (radians)
    lon0 = -2*pi/180                    #Longtitude of true origin and central meridian (radians)
    N0, E0 = -100000, 400000            #Northing & easting of true origin (m)
    e2 = 1 - (b*b)/(a*a)                #eccentricity squared
    n = (a-b)/(a+b)

    #Initialise the iterative variables
    lat,M = lat0, 0

    while N-N0-M >= 0.00001: #Accurate to 0.01mm
        lat = (N-N0-M)/(a*F0) + lat;
        M1 = (1 + n + (5./4)*n**2 + (5./4)*n**3) * (lat-lat0)
        M2 = (3*n + 3*n**2 + (21./8)*n**3) * sin(lat-lat0) * cos(lat+lat0)
        M3 = ((15./8)*n**2 + (15./8)*n**3) * sin(2*(lat-lat0)) * cos(2*(lat+lat0))
        M4 = (35./24)*n**3 * sin(3*(lat-lat0)) * cos(3*(lat+lat0))
        #meridional arc
        M = b * F0 * (M1 - M2 + M3 - M4)          

    #transverse radius of curvature
    nu = a*F0/sqrt(1-e2*sin(lat)**2)

    #meridional radius of curvature
    rho = a*F0*(1-e2)*(1-e2*sin(lat)**2)**(-1.5)
    eta2 = nu/rho-1

    secLat = 1./cos(lat)
    VII = tan(lat)/(2*rho*nu)
    VIII = tan(lat)/(24*rho*nu**3)*(5+3*tan(lat)**2+eta2-9*tan(lat)**2*eta2)
    IX = tan(lat)/(720*rho*nu**5)*(61+90*tan(lat)**2+45*tan(lat)**4)
    X = secLat/nu
    XI = secLat/(6*nu**3)*(nu/rho+2*tan(lat)**2)
    XII = secLat/(120*nu**5)*(5+28*tan(lat)**2+24*tan(lat)**4)
    XIIA = secLat/(5040*nu**7)*(61+662*tan(lat)**2+1320*tan(lat)**4+720*tan(lat)**6)
    dE = E-E0

    #These are on the wrong ellipsoid currently: Airy1830. (Denoted by _1)
    lat_1 = lat - VII*dE**2 + VIII*dE**4 - IX*dE**6
    lon_1 = lon0 + X*dE - XI*dE**3 + XII*dE**5 - XIIA*dE**7

    #Want to convert to the GRS80 ellipsoid. 
    #First convert to cartesian from spherical polar coordinates
    H = 0 #Third spherical coord. 
    x_1 = (nu/F0 + H)*cos(lat_1)*cos(lon_1)
    y_1 = (nu/F0+ H)*cos(lat_1)*sin(lon_1)
    z_1 = ((1-e2)*nu/F0 +H)*sin(lat_1)

    #Perform Helmut transform (to go between Airy 1830 (_1) and GRS80 (_2))
    s = -20.4894*10**-6 #The scale factor -1
    tx, ty, tz = 446.448, -125.157, + 542.060 #The translations along x,y,z axes respectively
    rxs,rys,rzs = 0.1502,  0.2470,  0.8421  #The rotations along x,y,z respectively, in seconds
    rx, ry, rz = rxs*pi/(180*3600.), rys*pi/(180*3600.), rzs*pi/(180*3600.) #In radians
    x_2 = tx + (1+s)*x_1 + (-rz)*y_1 + (ry)*z_1
    y_2 = ty + (rz)*x_1  + (1+s)*y_1 + (-rx)*z_1
    z_2 = tz + (-ry)*x_1 + (rx)*y_1 +  (1+s)*z_1

    #Back to spherical polar coordinates from cartesian
    #Need some of the characteristics of the new ellipsoid    
    a_2, b_2 =6378137.000, 6356752.3141 #The GSR80 semi-major and semi-minor axes used for WGS84(m)
    e2_2 = 1- (b_2*b_2)/(a_2*a_2)   #The eccentricity of the GRS80 ellipsoid
    p = sqrt(x_2**2 + y_2**2)

    #Lat is obtained by an iterative proceedure:   
    lat = arctan2(z_2,(p*(1-e2_2))) #Initial value
    latold = 2*pi
    while abs(lat - latold)>10**-16: 
        lat, latold = latold, lat
        nu_2 = a_2/sqrt(1-e2_2*sin(latold)**2)
        lat = arctan2(z_2+e2_2*nu_2*sin(latold), p)

    #Lon and height are then pretty easy
    lon = arctan2(y_2,x_2)
    H = p/cos(lat) - nu_2

#Uncomment this line if you want to print the results
    #print [(lat-lat_1)*180/pi, (lon - lon_1)*180/pi]

    #Convert to degrees
    lat = lat*180/pi
    lon = lon*180/pi

    #Job's a good'n. 
    return lat, lon

# %%
OSGB36toWGS84(460638.3 , 87258.3)
# Out:
# (50.68183120930284, -1.1430709918571467)

# %%
import pandas as pd

# %%
def applicationTrackingTable(p):
    data={}
    t=BeautifulSoup(p).find('div',id='pnlTracking').find('table')
    for row in t.findAll('tr'):
        cells=row.findAll('td')
        cn=re.sub('[\r\t\n]','',cells[0].text).strip().strip(':').replace(u'\xa0',' ')
        data[cn]=cells[1].text.strip()
        try:
            data[cn+'_t']=parser.parse(data[cn], dayfirst=True)
        except: 
            data[cn+'_t']=None
    return data

# %%
import re
def planningAppCleaner(t):
    data={}
    for row in t.findAll('tr')[1:]:
        cells=row.findAll('td')
        key=re.sub('[\r\t\n]','',cells[0].text).strip().strip(':').replace(u'\xa0',' ')
        data[key]=re.sub('[\r\t]','',re.sub('\s\s+',' ',cells[1].text.replace(u'\xa0',' '))).strip()
    en=data['Easting/Northing'].split('/')
    data['easting']=float(en[0].strip())
    data['northing']=float(en[1].strip())
    return data

def iwPlanPageScrape(stub):
    urlbase='https://www.iwight.com/planning/'
    url=urlbase+stub
    p=requests.get(url)
    t=BeautifulSoup(p.content.replace('<br/>','\n')).find('table',id='summarydetails')
    data=planningAppCleaner(t)
    data.update(applicationTrackingTable(p.content))
    return data

iwPlanPageScrape('AppDetails3.aspx?frmId=29636')
# Out:
# {u'Agent or Applicant': u'Mr S Clutterbuck ClutterbuckEdwards\nChartered Architect and Surveyor Heather House Newport Road Niton Isle of Wight PO38 2DQ\n01983 731111 / 533444',
#  u'Appeal Date': u'N/A',
#  u'Appeal Date_t': None,
#  u'Appeal Decision Date': u'N/A',
#  u'Appeal Decision Date_t': None,
#  u'Case Officer': u'Lizzy Hardy',
#  u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#  u'Committee Date': u'N/A',
#  u'Committee Date_t': None,
#  u'Consultation End Date': u'05/06/2015',
#  u'Consultation End Date_t': datetime.datetime(2015, 6, 5, 0, 0),
#  u'Consultation Start Date': u'15/05/2015',
#  u'Consultation Start Date_t': datetime.datetime(2015, 5, 15, 0, 0),
#  u'Decision Date': u'Not yet available',
#  u'Decision Date_t': None,
#  u'Easting/Northing': u'453358.5 / 86765.9',
#  u'Location': u'Arreton Barns Main Road Arreton Newport Isle Of Wight PO30',
#  u'Parish': u'Arreton',
#  u'Proposal': u'Proposed construction of 2 craft workshops',
#  u'Publicity Date': u'15/05/2015',
#  u'Received ': u'22/04/2015',
#  u'Received _t': datetime.datetime(2015, 4, 22, 0, 0),
#  u'Registered / Validated': u'22/04/2015',
#  u'Registered / Validated_t': datetime.datetime(2015, 4, 22, 0, 0),
#  u'Ward': u'Arreton and Newchurch',
#  'easting': 453358.5,
#  'northing': 86765.9}

# %%
from dateutil import parser
import datetime 

soup=BeautifulSoup(r.content)
t=soup.find('table',id='dgResults')
data=[]
for row in t.findAll('tr')[1:]:
    d={}
    cells= row.findAll('td')
    d['ref']=cells[0].find('a').text.strip()
    d['stub']=cells[0].find('a')['href']
    d['addr']=cells[1].text.strip()
    d['desc']=cells[2].text.strip()
    d['commentsBy']=cells[3].text.strip()
    d['commentsByDate']=d['commentsBy'].replace('Comments Due By:','').strip()
    try:
        d['commentsByDate']=parser.parse(d['commentsByDate'], dayfirst=True)
    except: d['commentsByDate']=None
    d['scrapetime']=datetime.datetime.utcnow()
    d.update(iwPlanPageScrape(d['stub']))
    d['lat'],d['lon']=OSGB36toWGS84(d['easting'],d['northing'])
    data.append(d)
df=pd.DataFrame(data)
# Out:
# (<tr class="dbResults" valign="top">
# <td><a href="AppDetails3.aspx?frmId=29636">TCPL/30030/E - P/00492/15<br/></a></td><td>Arreton Barns Main Road Arreton Newport Isle Of Wight PO30</td><td>Proposed construction of 2 craft workshops</td><td>Comments Due By: 05/06/2015  </td>
# </tr>, u'05/06/2015')
# (<tr class="dbResults" valign="top">
# <td><a href="AppDetails3.aspx?frmId=29637">LBC/30030/D - P/00493/15<br/></a></td><td>Arreton Barns Main Road Arreton Newport Isle Of Wight PO30</td><td>LBC for proposed construction of 2 craft workshops</td><td>Comments Due By: 05/06/2015  </td>
# </tr>, u'05/06/2015')
# (<tr class="dbResults" valign="top">
# <td><a href="AppDetails3.aspx?frmId=29640">TCP/18057/A - P/00504/15<br/></a></td><td>11 Fishbourne Lane Ryde Isle Of Wight PO334EZ</td><td>Householder Application  Demolition of garage and porch two storey extension on south elevation and single storey extension on north elevation to provide additional living accommodation to include balcony on west elevation detached garage/workshop</td><td>Comments Due By: 05/06/2015  </td>
# </tr>, u'05/06/2015')
# (<tr class="dbResults" valign="top">
# <td><a href="AppDetails3.aspx?frmId=29638">TCP/28874/D - P/00512/15<br/></a></td><td>St. Veronica Lane End Road Bembridge Isle Of Wight PO355TB</td><td>Change of use from bed and breakfast to a single dwelling (revised scheme)</td><td>Comments Due By: 05/06/2015  </td>
# </tr>, u'05/06/2015')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-163-afe3b663d815> in <module>()
#      15     print(row,d['commentsByDate'])
#      16     d['commentsByDate']=parser.parse(d['commentsByDate'], dayfirst=True)
# ---> 17     d.update(iwPlanPageScrape(d['stub']))
#      18     d['lat'],d['lon']=OSGB36toWGS84(d['easting'],d['northing'])
#      19     data.append(d)
#
# <ipython-input-87-b26ea806df83> in iwPlanPageScrape(stub)
#      14     urlbase='https://www.iwight.com/planning/'
#      15     url=urlbase+stub
# ---> 16     p=requests.get(url)
#      17     t=BeautifulSoup(p.content.replace('<br/>','\n')).find('table',id='summarydetails')
#      18     data=planningAppCleaner(t)
#
# /Users/ajh59/anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, **kwargs)
#      66
#      67     kwargs.setdefault('allow_redirects', True)
# ---> 68     return request('get', url, **kwargs)
#      69
#      70
#
# /Users/ajh59/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
#      52     # can trigger a ResourceWarning in some cases, and look like a memory leak
#
# /Users/ajh59/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     462         }
#     463         send_kwargs.update(settings)
# --> 464         resp = self.send(prep, **send_kwargs)
#     465
#     466         return resp
#
# /Users/ajh59/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /Users/ajh59/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# /Users/ajh59/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     542             httplib_response = self._make_request(conn, method, url,
#     543                                                   timeout=timeout_obj,
# --> 544                                                   body=body, headers=headers)
#     545
#     546             # If we're going to release the connection in ``finally:``, then
#
# /Users/ajh59/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     370         try:
#     371             try:  # Python 2.7, use buffering of HTTP responses
# --> 372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
#     374                 httplib_response = conn.getresponse()
#
# /Users/ajh59/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1071         response = self.response_class(*args, **kwds)
#    1072
# -> 1073         response.begin()
#    1074         assert response.will_close != _UNKNOWN
#    1075         self.__state = _CS_IDLE
#
# /Users/ajh59/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     413         # read until we get a non-100 response
#     414         while True:
# --> 415             version, status, reason = self._read_status()
#     416             if status != CONTINUE:
#     417                 break
#
# /Users/ajh59/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     369     def _read_status(self):
#     370         # Initialize with Simple-Response defaults
# --> 371         line = self.fp.readline(_MAXLINE + 1)
#     372         if len(line) > _MAXLINE:
#     373             raise LineTooLong("header line")
#
# /Users/ajh59/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     474             while True:
#     475                 try:
# --> 476                     data = self._sock.recv(self._rbufsize)
#     477                 except error, e:
#     478                     if e.args[0] == EINTR:
#
# /Users/ajh59/anaconda/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     712                     "non-zero flags not allowed in calls to recv() on %s" %
#     713                     self.__class__)
# --> 714             return self.read(buflen)
#     715         else:
#     716             return self._sock.recv(buflen, flags)
#
# /Users/ajh59/anaconda/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     606                 v = self._sslobj.read(len, buffer)
#     607             else:
# --> 608                 v = self._sslobj.read(len or 1024)
#     609             return v
#     610         except SSLError as x:
#
# KeyboardInterrupt:

# %%
data
# Out:
# [{u'Agent or Applicant': u'Mr S Clutterbuck ClutterbuckEdwards\nChartered Architect and Surveyor Heather House Newport Road Niton Isle of Wight PO38 2DQ\n01983 731111 / 533444',
#   u'Case Officer': u'Lizzy Hardy',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'453358.5 / 86765.9',
#   u'Location': u'Arreton Barns Main Road Arreton Newport Isle Of Wight PO30',
#   u'Parish': u'Arreton',
#   u'Proposal': u'Proposed construction of 2 craft workshops',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Arreton and Newchurch',
#   'addr': u'Arreton Barns Main Road Arreton Newport Isle Of Wight PO30',
#   'commentsBy': u'Comments Due By: 05/06/2015',
#   'commentsByDate': datetime.datetime(2015, 6, 5, 0, 0),
#   'desc': u'Proposed construction of 2 craft workshops',
#   'easting': 453358.5,
#   'lat': 50.67811526176241,
#   'lon': -1.2461721482484642,
#   'northing': 86765.9,
#   'ref': u'TCPL/30030/E - P/00492/15',
#   'stub': 'AppDetails3.aspx?frmId=29636'},
#  {u'Agent or Applicant': u'Mr S Clutterbuck ClutterbuckEdwards\nChartered Architect and Surveyor Heather House Newport Road Niton Isle of Wight PO38 2DQ\n01983 731111 / 533444',
#   u'Case Officer': u'Lizzy Hardy',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'453358.5 / 86765.9',
#   u'Location': u'Arreton Barns Main Road Arreton Newport Isle Of Wight PO30',
#   u'Parish': u'Arreton',
#   u'Proposal': u'LBC for proposed construction of 2 craft workshops',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Arreton and Newchurch',
#   'addr': u'Arreton Barns Main Road Arreton Newport Isle Of Wight PO30',
#   'commentsBy': u'Comments Due By: 05/06/2015',
#   'commentsByDate': datetime.datetime(2015, 6, 5, 0, 0),
#   'desc': u'LBC for proposed construction of 2 craft workshops',
#   'easting': 453358.5,
#   'lat': 50.67811526176241,
#   'lon': -1.2461721482484642,
#   'northing': 86765.9,
#   'ref': u'LBC/30030/D - P/00493/15',
#   'stub': 'AppDetails3.aspx?frmId=29637'},
#  {u'Agent or Applicant': u'Mr A Hitt Andrew E Hitt\nCorner House 6870 Lugley Street Newport Isle of Wight PO30 5ET',
#   u'Case Officer': u'Hayley Byrne',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'455510.9 / 92274.4',
#   u'Location': u'11 Fishbourne Lane Ryde Isle Of Wight PO334EZ',
#   u'Parish': u'Fishbourne',
#   u'Proposal': u'Householder Application Demolition of garage and porch two storey extension on south elevation and single storey extension on north elevation to provide additional living accommodation to include balcony on west elevation detached garage/workshop',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Binstead and Fishbourne',
#   'addr': u'11 Fishbourne Lane Ryde Isle Of Wight PO334EZ',
#   'commentsBy': u'Comments Due By: 05/06/2015',
#   'commentsByDate': datetime.datetime(2015, 6, 5, 0, 0),
#   'desc': u'Householder Application  Demolition of garage and porch two storey extension on south elevation and single storey extension on north elevation to provide additional living accommodation to include balcony on west elevation detached garage/workshop',
#   'easting': 455510.9,
#   'lat': 50.727445980531584,
#   'lon': -1.214885482779481,
#   'northing': 92274.4,
#   'ref': u'TCP/18057/A - P/00504/15',
#   'stub': 'AppDetails3.aspx?frmId=29640'}]

# %%
df.to_csv('iwplanning.csv')

# %%
df.columns
# Out:
# Index([u'Agent or Applicant', u'Case Officer', u'Comments Date', u'Easting/Northing', u'Location', u'Parish', u'Proposal', u'Publicity Date', u'Ward', u'addr', u'commentsBy', u'easting', u'lat', u'lon', u'northing', u'ref', u'stub'], dtype='object')

# %%
df
# Out:
#                                    Agent or Applicant          Case Officer  \
# 0   Mr S Clutterbuck ClutterbuckEdwards\nChartered...           Lizzy Hardy
# 1   Mr S Clutterbuck ClutterbuckEdwards\nChartered...           Lizzy Hardy
# 2   Mr A Hitt Andrew E Hitt\nCorner House 6870 Lug...          Hayley Byrne
# 3   Mr J Gosling J P Designs\nSunny Heights Arnold...        Richard Holmes
# 4                                                              Hayley Byrne
# 5   Mr A Hitt Andrew E Hitt\nCorner House 6870 Lug...          Hayley Byrne
# 6                                                               Sarah Gooch
# 7   Mr R Parker Endpoint Ltd\n165 Tower Bridge Roa...       Sarah Wilkinson
# 8   Mr L Hibberd Simply Draughting\n7 Falcon Road ...          Hayden Marsh
# 9   Mr David Holbrook Ford Cottage 9 Clatterford S...          Hayden Marsh
# 10  Mr M Jones MD Jones Architectural Services\nSu...        Richard Holmes
# 11  Ms K Priest Pegasus Planning Group Ltd\nFirst ...          Hayley Byrne
# 12  Ms K Priest Pegasus Planning Group Ltd\nFirst ...          Hayley Byrne
# 13  Ms K Priest Pegasus Planning Group Ltd\nFirst ...          Hayley Byrne
# 14  Mr R Gray Robert Gray Design Ltd\n12 Donningto...          Hayden Marsh
# 15  Mr J Sackett Apple Panels\nBuilding 397 Aviati...           Sarah Gooch
# 16                                                              Sarah Gooch
# 17  Mr N White 36a West Street Ryde Isle of Wight ...          Hayden Marsh
# 18  Miss R Mahendran MG Architects\n2 Northfields ...          Hayden Marsh
# 19  Mr J Gosling J P Designs\nSunny Heights Arnold...           Sarah Gooch
# 20  Mrs C Howlett Hepburns Planning Consultancy Lt...        Richard Holmes
# 21  C A Fairweather A.I.P.D\nKingfishers 36A Merri...        Richard Holmes
# 2   Comments on this Application must be received ...  455510.9 / 92274.4
# 3   Comments on this Application must be received ...  465580.9 / 88076.2
# 4   Comments on this Application must be received ...  449496.7 / 96381.4
# 5   Comments on this Application must be received ...  447736.2 / 93576.1
# 6   Comments on this Application must be received ...  455855.2 / 79217.9
# 7   Comments on this Application must be received ...  458161.2 / 83363.0
# 8   Comments on this Application must be received ...  458719.8 / 82344.1
# 9   Comments on this Application must be received ...  462473.5 / 90410.7
# 10  Comments on this Application must be received ...  462574.9 / 90110.0
# 11  Comments on this Application must be received ...  449720.7 / 89148.3
# 12  Comments on this Application must be received ...  449720.7 / 89148.3
# 13  Comments on this Application must be received ...  449720.7 / 89148.3
# 14  Comments on this Application must be received ...  459736.5 / 84167.4
# 15  Comments on this Application must be received ...  455670.0 / 77653.3
# 16  Comments on this Application must be received ...  435944.5 / 89645.4
# 17  Comments on this Application must be received ...  456605.1 / 84170.9
# 18  Comments on this Application must be received ...  464148.7 / 87932.9
# 19  Comments on this Application must be received ...  460638.3 / 87258.3
# 20  Comments on this Application must be received ...  442617.4 / 81984.3
# 21  Comments on this Application must be received ...  451109.4 / 83982.2
# 22  Comments on this Application must be received ...  450577.9 / 76713.0
# 23  Comments on this Application must be received ...  447166.7 / 95312.0
# 24  Comments on this Application must be received ...  434033.2 / 88173.7
# 25  Comments on this Application must be received ...  434326.3 / 87044.3
# 26  Comments on this Application must be received ...  452612.2 / 81087.4
# 27  Comments on this Application must be received ...  455305.6 / 81351.9
# 28  Comments on this Application must be received ...  458783.3 / 91544.1
# 29  Comments on this Application must be received ...  449823.0 / 89340.3
# ..                                                ...                 ...
# 57  Comments on this Application must be received ...  462883.4 / 91539.5
# 58  Comments on this Application must be received ...  449864.9 / 88996.8
# 59  Comments on this Application must be received ...  450214.8 / 89035.5
# 60  Comments on this Application must be received ...  449269.5 / 88476.3
# 61  Comments on this Application must be received ...  432689.4 / 87333.3
# 62  Comments on this Application must be received ...  439796.3 / 90752.3
# 63  Comments on this Application must be received ...  435533.7 / 89672.0
# 64  Comments on this Application must be received ...  453842.9 / 91900.0
# 65  Comments on this Application must be received ...  455522.5 / 89801.2
# 66  Comments on this Application must be received ...  458076.1 / 85698.9
# 67  Comments on this Application must be received ...  447729.6 / 89197.6
# 68  Comments on this Application must be received ...  448076.1 / 88961.6
# 69  Comments on this Application must be received ...  450561.5 / 76716.0
# 70  Comments on this Application must be received ...  448510.1 / 93521.9
# 71  Comments on this Application must be received ...  448411.4 / 95389.4
# 72  Comments on this Application must be received ...  447559.2 / 95349.8
# 73  Comments on this Application must be received ...  455027.5 / 79881.3
# 74  Comments on this Application must be received ...  458165.7 / 90241.5
# 75  Comments on this Application must be received ...  462779.2 / 91619.4
# 76  Comments on this Application must be received ...  463060.3 / 91338.8
# 77  Comments on this Application must be received ...  462096.1 / 91892.9
# 78  Comments on this Application must be received ...  449815.2 / 89116.2
# 79  Comments on this Application must be received ...  460074.1 / 92558.3
# 80  Comments on this Application must be received ...  459281.6 / 92798.3
# 73  former public conveniences Grove Road Wroxall ...
# 74  Robeck Registered Caravan and Camping Site Gat...
# 75  British Telecom Telephone Exchange Fairy Road ...
# 76  Ground Floor Apartment Sandcove Pier Road Seav...
# 77  Isle Of Wight Self Catering Ltd Salterns Road ...
# 78       53 High Street Newport Isle Of Wight PO301SB
# 79  memorial gardens adjacent to 29 The Strand Ryd...
# 80        13a Union Street Ryde Isle Of Wight PO332DU
# 81       17 Avenue Road Sandown Isle Of Wight PO368BN
# 82  land west of Gustar Grove/Captains Parade/Abbe...
# 83  41 Lushington Hill Wootton Bridge Ryde Isle Of...
# 84  The Coach House Woodlands Vale Calthorpe Road ...
# 85      12 Holyrood Street Newport Isle Of Wight PO30
# 86      12 Holyrood Street Newport Isle Of Wight PO30
#
#                      Parish  \
# 0                   Arreton
# 1                   Arreton
# 2                Fishbourne
# 3                 Bembridge
# 4                     Cowes
# 5                 Northwood
# 6                   Wroxall
# 7                      Lake
# 8                  Shanklin
# 9   Nettlestone and Seaview
# 10  Nettlestone and Seaview
# 11                  Newport
# 12                  Newport
# 13                  Newport
# 14                  Sandown
# 15                  Ventnor
# 16                 Yarmouth
# 17                Newchurch
# 18                Bembridge
# 19                  Brading
# 20               Brighstone
# 21                  Rookley
# 22       Niton and Whitwell
# 23                  Gurnard
# 24               Freshwater
# 25               Freshwater
# 26                 Godshill
# 27                  Wroxall
# 28                     Ryde
# 29                  Newport
# ..                      ...
# 57  Nettlestone and Seaview
# 58                  Newport
# 59                  Newport
# 60                  Newport
# 61                  Totland
# 62                Shalfleet
# 63                 Yarmouth
# 64           Wootton Bridge
# 65           Wootton Bridge
# 66                Newchurch
# 67                  Newport
# 68                  Newport
# 69       Niton and Whitwell
# 70                Northwood
# 71                    Cowes
# 72                  Gurnard
# 73                  Wroxall
# 74    Havenstreet and Ashey
# 75  Nettlestone and Seaview
# 76  Nettlestone and Seaview
# 77  Nettlestone and Seaview
# 78                  Newport
# 79                     Ryde
# 80                     Ryde
# 81                  Sandown
# 82               East Cowes
# 83           Wootton Bridge
# 84  Nettlestone and Seaview
# 85                  Newport
# 86                  Newport
#
#                                              Proposal Publicity Date  \
# 0          Proposed construction of 2 craft workshops     15/05/2015
# 1   LBC for proposed construction of 2 craft works...     15/05/2015
# 2   Householder Application Demolition of garage a...     15/05/2015
# 3   Change of use from bed and breakfast to a sing...     15/05/2015
# 4   Proposed alterations to front elevation new ro...     15/05/2015
# 5   Householder Application Single storey rear ext...     15/05/2015
# 6           Householder Application Proposed car port     15/05/2015
# 7   Advertisement Consent Application 1 x internal...     15/05/2015
# 8   Householder Application Demolition of conserva...     15/05/2015
# 9   Householder Application Alterations single sto...     15/05/2015
# 10  Temporary siting of portable buildings with as...     15/05/2015
# 11  Change of use from post office to restaurant i...     15/05/2015
# 12  Minor Commercial (Shop Front) Application Alte...     15/05/2015
# 13  LBC for demolition of outbuildings and interna...     15/05/2015
# 14  Alterations and change of use of ground floor ...     15/05/2015
# 15      Householder Application Proposed conservatory     15/05/2015
# 16  Householder Application Demolition of balcony ...     15/05/2015
# 17  Householder Application Demolition of conserva...     08/05/2015
# 18  Householder Application Proposed single storey...     08/05/2015
# 19  Alterations replacement of flat roof to single...     08/05/2015
# 20  Variation of condition no. 3 and removal of co...     08/05/2015
# 21  Change of use of former steel fabricators to c...     08/05/2015
# 22               Householder Application Conservatory     08/05/2015
# 23      Householder Application Proposed summer house     08/05/2015
# 24  Variation of condition no. 2 on TCP/3664/L/RD ...     08/05/2015
# 25  Demolition of building outline for residential...     08/05/2015
# 26  Householder Application Proposed single storey...     08/05/2015
# 27             Proposed roundhouse livestock building     08/05/2015
# 28  Householder Application Demolition of single s...     08/05/2015
# 29  Change of use from office accommodation to a d...     08/05/2015
# ..                                                ...            ...
# 57  Householder Application Demolition of outbuild...     01/05/2015
# 58  Variation of condition no. 4 on TCP/23026 P/00...     01/05/2015
# 59                  Great War commemoration sculpture     01/05/2015
# 60  Alterations to and change of use of bakery to ...     01/05/2015
# 61  Variation of condition no. 2 on P/00109/14 TCP...     01/05/2015
# 62                      Agricultural workers dwelling     01/05/2015
# 63  Householder Application Proposed extension at ...     01/05/2015
# 64  Householder Application Demolition of rear sin...     01/05/2015
# 65  Change of use of section of land to form falco...     01/05/2015
# 66      Retention of agricultural workers mobile home     24/04/2015
# 67  Outline for 50 dwellings (mix of affordable ho...     24/04/2015
# 68                     Proposed dwelling with parking     24/04/2015
# 69  Variation of condition no. 2 on APP/P2114/A/12...     24/04/2015
# 70  Householder Application Proposed dormer window...     24/04/2015
# 71  Householder Application Alterations and enlarg...     24/04/2015
# 72  Householder Application Demolition of conserva...     24/04/2015
# 73  Alterations single storey extension on front e...     24/04/2015
# 74  Replacement of 6 existing holiday caravans wit...     24/04/2015
# 75  Alterations and change of use of building to p...     24/04/2015
# 76  Householder Application Alterations single sto...     24/04/2015
# 77  Advertisement Consent Application 2 x flag pol...     24/04/2015
# 78  Advertisement Consent Application 2 illuminate...     24/04/2015
# 79                        Proposed ventilation column     24/04/2015
# 80  Change of use of 2nd floor flat to form additi...     24/04/2015
# 81  Alterations and two storey extension on south ...     24/04/2015
# 82  Approval of reserved matters for the appearanc...     24/04/2015
# 83  Proposed change of use alterations and single ...     24/04/2015
# 84  Householder Application Proposed outbuilding t...     17/04/2015
# 85  Alterations and three storey rear/side extensi...     30/01/2015
# 86  LBC for alterations and three storey rear/side...     30/01/2015
#
#                                Ward  \
# 0             Arreton and Newchurch
# 1             Arreton and Newchurch
# 2           Binstead and Fishbourne
# 3   Brading St Helens and Bembridge
# 4                       Cowes North
# 5         Cowes South and Northwood
# 6              Godshill and Wroxall
# 7                        Lake South
# 8                        Lake South
# 9           Nettlestone and Seaview
# 10          Nettlestone and Seaview
# 11                  Newport Central
# 12                  Newport Central
# 13                  Newport Central
# 14                    Sandown South
# 15                     Ventnor West
# 16                       West Wight
# 17            Arreton and Newchurch
# 18  Brading St Helens and Bembridge
# 19  Brading St Helens and Bembridge
# 20                    Central Wight
# 21                    Central Wight
# 5   AppDetails3.aspx?frmId=29647
# 6   AppDetails3.aspx?frmId=29634
# 7   AppDetails3.aspx?frmId=29641
# 8   AppDetails3.aspx?frmId=29649
# 9   AppDetails3.aspx?frmId=29642
# 10  AppDetails3.aspx?frmId=29643
# 11  AppDetails3.aspx?frmId=29644
# 12  AppDetails3.aspx?frmId=29645
# 13  AppDetails3.aspx?frmId=29646
# 14  AppDetails3.aspx?frmId=29648
# 15  AppDetails3.aspx?frmId=29633
# 16  AppDetails3.aspx?frmId=29635
# 17  AppDetails3.aspx?frmId=29618
# 18  AppDetails3.aspx?frmId=29603
# 19  AppDetails3.aspx?frmId=29604
# 20  AppDetails3.aspx?frmId=29605
# 21  AppDetails3.aspx?frmId=29629
# 22  AppDetails3.aspx?frmId=29628
# 23  AppDetails3.aspx?frmId=29609
# 24  AppDetails3.aspx?frmId=29606
# 25  AppDetails3.aspx?frmId=29607
# 26  AppDetails3.aspx?frmId=29608
# 27  AppDetails3.aspx?frmId=29617
# 28  AppDetails3.aspx?frmId=29630
# 29  AppDetails3.aspx?frmId=29619
# ..                           ...
# 57  AppDetails3.aspx?frmId=29599
# 58  AppDetails3.aspx?frmId=29592
# 59  AppDetails3.aspx?frmId=29593
# 60  AppDetails3.aspx?frmId=29594
# 61  AppDetails3.aspx?frmId=29597
# 62  AppDetails3.aspx?frmId=29595
# 63  AppDetails3.aspx?frmId=29602
# 64  AppDetails3.aspx?frmId=29598
# 65  AppDetails3.aspx?frmId=29600
# 66  AppDetails3.aspx?frmId=29578
# 67  AppDetails3.aspx?frmId=29579
# 68  AppDetails3.aspx?frmId=29580
# 69  AppDetails3.aspx?frmId=29582
# 70  AppDetails3.aspx?frmId=29583
# 71  AppDetails3.aspx?frmId=29571
# 72  AppDetails3.aspx?frmId=29573
# 73  AppDetails3.aspx?frmId=29569
# 74  AppDetails3.aspx?frmId=29574
# 75  AppDetails3.aspx?frmId=29575
# 76  AppDetails3.aspx?frmId=29576
# 77  AppDetails3.aspx?frmId=29577
# 78  AppDetails3.aspx?frmId=29581
# 79  AppDetails3.aspx?frmId=29565
# 80  AppDetails3.aspx?frmId=29566
# 81  AppDetails3.aspx?frmId=29567
# 82  AppDetails3.aspx?frmId=29572
# 83  AppDetails3.aspx?frmId=29568
# 84  AppDetails3.aspx?frmId=29554
# 85  AppDetails3.aspx?frmId=29224
# 86  AppDetails3.aspx?frmId=29225
#
# [87 rows x 17 columns]

# %%
#Probably need to install folium
#!pip install folium

#A couple of standard helper routines to preview the maps.

from IPython.display import HTML

import folium
reload(folium)

def mapfix(path):
    f=open(path,'r')
    html=f.read()
    f.close()
    html=html.replace('"//','"http://')
    f=open(path,'w')
    f.write(html)
    f.close()
    
def inline_map(map):
    """
    Embeds the HTML source of the map directly into the IPython notebook.
    
    This method will not work if the map depends on any files (json data). Also this uses
    the HTML5 srcdoc attribute, which may not be supported in all browsers.
    """
    map._build_map()
    return HTML('<iframe srcdoc="{srcdoc}" style="width: 100%; height: 510px; border: none"></iframe>'.format(srcdoc=map.HTML.replace('"', '&quot;')))

#The embed_map approach saves an HTML file that generates the map if you access if access it via a webserver
#The server stuff is all handled for you when viewing the map in an IPython notebook
def embed_map(map, path="map.html"):
    """
    Embeds a linked iframe to the map into the IPython notebook.
    
    Note: this method will not capture the source of the map into the notebook.
    This method should work for all maps (as long as they use relative urls).
    """
    map.create_map(path=path)
    mapfix(path)
    return HTML('<iframe src="files/{path}" style="width: 100%; height: 510px; border: none"></iframe>'.format(path=path))

# %%
def mapper(tmp,df):
    for row in df[ df['lon'].notnull() ].iterrows():
        #print(row[1]['Latitude'],row[1]['Latitude'])
        #Define a template that will contain information in the pop-up marker
        template='<strong>{proposal}</strong><br/>Agent: {agent}<br/><em>Location:</em> {location}'
        tmp.simple_marker([row[1]['lat'], row[1]['lon']],
                          popup=template.format(agent=row[1]['Agent or Applicant'],
                                                proposal=row[1]['Proposal'],
                                                location=row[1]['Location']
                                                ),
                          #This parameter switches on a feature of the leafle map library that auto-clusters numerous close markers
                          clustered_marker=True)
    return tmp

# %%
#Create a base map - I'm guessing the mid-pointlat-long - we should create it from the data...
longm=df[ df['lon'].notnull() ]['lon'].mean()
latm=df[ df['lat'].notnull() ]['lat'].mean()

planningmap = folium.Map(location=[latm, longm], zoom_start=11)
planningmap=mapper(planningmap,df)
#An example of generating the "inline" preview map
inline_map(planningmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;//rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_72801a2327ad431e9fe03e4cd2170077&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_72801a2327ad431e9fe03e4cd2170077', {
#                                        center:[50.6934948581, -1.25729129441],
#                                        zoom: 11,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([50.6781152618,
# 							-1.24617214825],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<strong>Proposed construction of 2 craft workshops</strong><br/>Agent: Mr S Clutterbuck ClutterbuckEdwards\nChartered Architect and Surveyor Heather House Newport Road Niton Isle of Wight PO38 2DQ\n01983 731111 / 533444<br/><em>Location:</em> Arreton Barns Main Road Arreton Newport Isle Of Wight PO30&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([50.6781152618,
# 							-1.24617214825],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<strong>LBC for proposed construction of 2 craft workshops</strong><br/>Agent: Mr S Clutterbuck ClutterbuckEdwards\nChartered Architect and Surveyor Heather House Newport Road Niton Isle of Wight PO38 2DQ\n01983 731111 / 533444<br/><em>Location:</em> Arreton Barns Main Road Arreton Newport Isle Of Wight PO30&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([50.7274459805,
# 							-1.21488548278],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<strong>Householder Application Demolition of garage and porch two storey extension on south elevation and single storey extension on north elevation to provide additional living accommodation to include balcony on west elevation detached garage/workshop</strong><br/>Agent: Mr A Hitt Andrew E Hitt\nCorner House 6870 Lugley Street Newport Isle of Wight PO30 5ET<br/><em>Location:</em> 11 Fishbourne Lane Ryde Isle Of Wight PO334EZ&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([50.6886502989,
# 							-1.0729765231],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<strong>Change of use from bed and breakfast to a single dwelling (revised scheme)</strong><br/>Agent: Mr J Gosling J P Designs\nSunny Heights Arnold Road Binstead Ryde Isle of Wight PO33 3RG\n01983 616768<br/><em>Location:</em> St. Veronica Lane End Road Bembridge Isle Of Wight PO355TB&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([50.764918334,
# 							-1.29953692973],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<strong>Proposed alterations to front elevation new roof to rear section of building</strong><br/>Agent: <br/><em>Location:</em> 10 Bath Road Cowes Isle Of Wight PO317QN&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([50.739840269,
# 							-1.32486054319],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<strong>Householder Application Single storey rear extension to enlarge living accommodation</strong><br/>Agent: Mr A Hitt Andrew E Hitt\nCorner House 6870 Lugley Street Newport Isle of Wight PO30 5ET<br/><em>Location:</em> 125 Pallance Road Cowes Isle Of Wight PO318LS&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([50.6100103328,
# 							-1.21197510224],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<strong>Householder

# %%
embed_map(planningmap)
# Out:
# <iframe src="files/map.html" style="width: 100%; height: 510px; border: none"></iframe>

# %%
#Probably need to install scraperwiki
#!pip install scraperwiki
import scraperwiki

# %%
tbdef={}
for i in df.columns:
    if df.dtypes[i]=='float64':
        tbdef[i]='real'
    else:
        tbdef[i]='text'
deflist=[]
for k in tbdef:
    deflist.append("'{}' {}".format(k,tbdef[k]))
dt="CREATE TABLE IF NOT EXISTS 'IWPLANNING' ({})".format(','.join(deflist))
print(dt)
# Out:
# CREATE TABLE IF NOT EXISTS 'IWPLANNING' ('commentsBy' text,'addr' text,'Parish' text,'Case Officer' text,'Easting/Northing' text,'lon' real,'Publicity Date' text,'stub' text,'Agent or Applicant' text,'Location' text,'easting' real,'lat' real,'Proposal' text,'Comments Date' text,'ref' text,'Ward' text,'northing' real)

# %%
def dropper(table,drop=False):
    """ Helper function to drop a table """
    if not drop: return
    print "dropping",table
    if table!='':
        try: scraperwiki.sqlite.execute('drop table "'+table+'"')
        except: pass

# %%
dropper('IWPLANNING',True)
scraperwiki.sqlite.execute(dt)
# Out:
# dropping IWPLANNING
# {u'data': [], u'keys': []}

# %%
scraperwiki.sqlite.save(unique_keys=['ref'],table_name='IWPLANNING', data=data)

# %%
grabbed=[x['ref'] for x in scraperwiki.sql.select("ref from IWPLANNING")]
grabbed
# Out:
# [u'TCPL/30030/E - P/00492/15',
#  u'LBC/30030/D - P/00493/15',
#  u'TCP/18057/A - P/00504/15',
#  u'TCP/28874/D - P/00512/15',
#  u'TCP/28415/C - P/00388/15',
#  u'TCP/32262 - P/00505/15',
#  u'TCP/32263 - P/00501/15',
#  u'A/02648/A - P/00509/15',
#  u'TCP/03387/C - P/00497/15',
#  u'TCP/32260 - P/00491/15',
#  u'TCP/08366/N - P/00502/15',
#  u'TCP/27885/E - P/00478/15',
#  u'TCP/27885/D - P/00490/15',
#  u'LBC/27885/F - P/00515/15',

#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'453358.5 / 86765.9',
#   u'Location': u'Arreton Barns Main Road Arreton Newport Isle Of Wight PO30',
#   u'Parish': u'Arreton',
#   u'Proposal': u'Proposed construction of 2 craft workshops',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Arreton and Newchurch',
#   'addr': u'Arreton Barns Main Road Arreton Newport Isle Of Wight PO30',
#   'commentsBy': u'Proposed construction of 2 craft workshops',
#   'easting': 453358.5,
#   'lat': 50.67811526176241,
#   'lon': -1.2461721482484642,
#   'northing': 86765.9,
#   'ref': u'TCPL/30030/E - P/00492/15',
#   'stub': 'AppDetails3.aspx?frmId=29636'},
#  {u'Agent or Applicant': u'Mr S Clutterbuck ClutterbuckEdwards\nChartered Architect and Surveyor Heather House Newport Road Niton Isle of Wight PO38 2DQ\n01983 731111 / 533444',
#   u'Case Officer': u'Lizzy Hardy',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'453358.5 / 86765.9',
#   u'Location': u'Arreton Barns Main Road Arreton Newport Isle Of Wight PO30',
#   u'Parish': u'Arreton',
#   u'Proposal': u'LBC for proposed construction of 2 craft workshops',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Arreton and Newchurch',
#   'addr': u'Arreton Barns Main Road Arreton Newport Isle Of Wight PO30',
#   'commentsBy': u'LBC for proposed construction of 2 craft workshops',
#   'easting': 453358.5,
#   'lat': 50.67811526176241,
#   'lon': -1.2461721482484642,
#   'northing': 86765.9,
#   'ref': u'LBC/30030/D - P/00493/15',
#   'stub': 'AppDetails3.aspx?frmId=29637'},
#  {u'Agent or Applicant': u'Mr A Hitt Andrew E Hitt\nCorner House 6870 Lugley Street Newport Isle of Wight PO30 5ET',
#   u'Case Officer': u'Hayley Byrne',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'455510.9 / 92274.4',
#   u'Location': u'11 Fishbourne Lane Ryde Isle Of Wight PO334EZ',
#   u'Parish': u'Fishbourne',
#   u'Proposal': u'Householder Application Demolition of garage and porch two storey extension on south elevation and single storey extension on north elevation to provide additional living accommodation to include balcony on west elevation detached garage/workshop',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Binstead and Fishbourne',
#   'addr': u'11 Fishbourne Lane Ryde Isle Of Wight PO334EZ',
#   'commentsBy': u'Householder Application  Demolition of garage and porch two storey extension on south elevation and single storey extension on north elevation to provide additional living accommodation to include balcony on west elevation detached garage/workshop',
#   'easting': 455510.9,
#   'lat': 50.727445980531584,
#   'lon': -1.214885482779481,
#   'northing': 92274.4,
#   'ref': u'TCP/18057/A - P/00504/15',
#   'stub': 'AppDetails3.aspx?frmId=29640'},
#  {u'Agent or Applicant': u'Mr J Gosling J P Designs\nSunny Heights Arnold Road Binstead Ryde Isle of Wight PO33 3RG\n01983 616768',
#   u'Case Officer': u'Richard Holmes',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'465580.9 / 88076.2',
#   u'Location': u'St. Veronica Lane End Road Bembridge Isle Of Wight PO355TB',
#   u'Parish': u'Bembridge',
#   u'Proposal': u'Change of use from bed and breakfast to a single dwelling (revised scheme)',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Brading St Helens and Bembridge',
#   'addr': u'St. Veronica Lane End Road Bembridge Isle Of Wight PO355TB',
#   'commentsBy': u'Change of use from bed and breakfast to a single dwelling (revised scheme)',
#   'easting': 465580.9,
#   'lat': 50.68865029889634,
#   'lon': -1.0729765231018262,
#   'northing': 88076.2,
#   'ref': u'TCP/28874/D - P/00512/15',
#   'stub': 'AppDetails3.aspx?frmId=29638'},
#  {u'Agent or Applicant': u'',
#   u'Case Officer': u'Hayley Byrne',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'449496.7 / 96381.4',
#   u'Location': u'10 Bath Road Cowes Isle Of Wight PO317QN',
#   u'Parish': u'Cowes',
#   u'Proposal': u'Proposed alterations to front elevation new roof to rear section of building',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Cowes North',
#   'addr': u'10 Bath Road Cowes Isle Of Wight PO317QN',
#   'commentsBy': u'Proposed alterations to front elevation new roof to rear section of building',
#   'easting': 449496.7,
#   'lat': 50.76491833404602,
#   'lon': -1.2995369297326904,
#   'northing': 96381.4,
#   'ref': u'TCP/28415/C - P/00388/15',
#   'stub': 'AppDetails3.aspx?frmId=29639'},
#  {u'Agent or Applicant': u'Mr A Hitt Andrew E Hitt\nCorner House 6870 Lugley Street Newport Isle of Wight PO30 5ET',
#   u'Case Officer': u'Hayley Byrne',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'447736.2 / 93576.1',
#   u'Location': u'125 Pallance Road Cowes Isle Of Wight PO318LS',
#   u'Parish': u'Northwood',
#   u'Proposal': u'Householder Application Single storey rear extension to enlarge living accommodation',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Cowes South and Northwood',
#   'addr': u'125 Pallance Road Cowes Isle Of Wight PO318LS',
#   'commentsBy': u'Householder Application  Single storey rear extension to enlarge living accommodation',
#   'easting': 447736.2,
#   'lat': 50.739840269029735,
#   'lon': -1.3248605431885685,
#   'northing': 93576.1,
#   'ref': u'TCP/32262 - P/00505/15',
#   'stub': 'AppDetails3.aspx?frmId=29647'},
#  {u'Agent or Applicant': u'',
#   u'Case Officer': u'Sarah Gooch',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'455855.2 / 79217.9',
#   u'Location': u'1 Cross Farm Cottages Manor Road Wroxall Ventnor Isle Of Wight PO383DF',
#   u'Parish': u'Wroxall',
#   u'Proposal': u'Householder Application Proposed car port',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Godshill and Wroxall',
#   'addr': u'1 Cross Farm Cottages Manor Road Wroxall Ventnor Isle Of Wight PO383DF',
#   'commentsBy': u'Householder Application  Proposed car port',
#   'easting': 455855.2,
#   'lat': 50.610010332759046,
#   'lon': -1.2119751022359428,
#   'northing': 79217.9,
#   'ref': u'TCP/32263 - P/00501/15',
#   'stub': 'AppDetails3.aspx?frmId=29634'},
#  {u'Agent or Applicant': u'Mr R Parker Endpoint Ltd\n165 Tower Bridge Road London Greater London SE1 3LW',
#   u'Case Officer': u'Sarah Wilkinson',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'458161.2 / 83363.0',
#   u'Location': u'Premier Inn Newport Road Sandown Isle Of Wight PO36',
#   u'Parish': u'Lake',
#   u'Proposal': u'Advertisement Consent Application 1 x internally illuminated totem sign (revised scheme)',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Lake South',
#   'addr': u'Premier Inn Newport Road Sandown Isle Of Wight PO36',
#   'commentsBy': u'Advertisement Consent Application  1 x internally illuminated totem sign (revised scheme)',
#   'easting': 458161.2,
#   'lat': 50.64705771251823,
#   'lon': -1.1787396809997581,
#   'northing': 83363.0,
#   'ref': u'A/02648/A - P/00509/15',
#   'stub': 'AppDetails3.aspx?frmId=29641'},
#  {u'Agent or Applicant': u'Mr L Hibberd Simply Draughting\n7 Falcon Road East Cowes Isle of Wight PO32 6SF',
#   u'Case Officer': u'Hayden Marsh',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'458719.8 / 82344.1',
#   u'Location': u'17 Littlestairs Road Shanklin Isle Of Wight PO376HR',
#   u'Parish': u'Shanklin',
#   u'Proposal': u'Householder Application Demolition of conservatory proposed enlarged conservatory',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Lake South',
#   'addr': u'17 Littlestairs Road Shanklin Isle Of Wight PO376HR',
#   'commentsBy': u'Householder Application  Demolition of conservatory proposed enlarged conservatory',
#   'easting': 458719.8,
#   'lat': 50.63783999192006,
#   'lon': -1.1710009757820714,
#   'northing': 82344.1,
#   'ref': u'TCP/03387/C - P/00497/15',
#   'stub': 'AppDetails3.aspx?frmId=29649'},
#  {u'Agent or Applicant': u'Mr David Holbrook Ford Cottage 9 Clatterford Shute Carisbrooke Newport Isle of Wight PO30 1PD\n01983 522159',
#   u'Case Officer': u'Hayden Marsh',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'462473.5 / 90410.7',
#   u'Location': u'Kara Mia Priory Drive Seaview Isle Of Wight PO345EA',
#   u'Parish': u'Nettlestone and Seaview',
#   u'Proposal': u'Householder Application Alterations single storey rear extension to provide bedroom and dining area proposed cladding',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Nettlestone and Seaview',
#   'addr': u'Kara Mia Priory Drive Seaview Isle Of Wight PO345EA',
#   'commentsBy': u'Householder Application  Alterations single storey rear extension to provide bedroom and dining area proposed cladding',
#   'easting': 462473.5,
#   'lat': 50.7099826706501,
#   'lon': -1.116566108957292,
#   'northing': 90410.7,
#   'ref': u'TCP/32260 - P/00491/15',
#   'stub': 'AppDetails3.aspx?frmId=29642'},
#  {u'Agent or Applicant': u'Mr M Jones MD Jones Architectural Services\nSuite 3 185a High Street Ryde Isle of Wight PO33 2PN\n612700',
#   u'Case Officer': u'Richard Holmes',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'462574.9 / 90110.0',
#   u'Location': u'Bucks Schools Camping Association Eddington Road Seaview Isle Of Wight PO345EE',
#   u'Parish': u'Nettlestone and Seaview',
#   u'Proposal': u'Temporary siting of portable buildings with associated parking and landscaping to provide medical centre as Business Continuity Plan in the event of devastating damage to the existing surgery (revised scheme)',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Nettlestone and Seaview',
#   'addr': u'Bucks Schools Camping Association Eddington Road Seaview Isle Of Wight PO345EE',
#   'commentsBy': u'Temporary siting of portable buildings with associated parking and landscaping to provide medical centre as Business Continuity Plan in the event of devastating damage to the existing surgery (revised scheme)',
#   'easting': 462574.9,
#   'lat': 50.707268005002355,
#   'lon': -1.1151810681632375,
#   'northing': 90110.0,
#   'ref': u'TCP/08366/N - P/00502/15',
#   'stub': 'AppDetails3.aspx?frmId=29643'},
#  {u'Agent or Applicant': u'Ms K Priest Pegasus Planning Group Ltd\nFirst Floor South Wing Equinox North Great Park Road Almondsbury Bristol BS32 4QL',
#   u'Case Officer': u'Hayley Byrne',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'449720.7 / 89148.3',
#   u'Location': u'former post office 99 High Street Newport Isle Of Wight PO301AB',
#   u'Parish': u'Newport',
#   u'Proposal': u'Change of use from post office to restaurant installation of extraction/ventilation equipment',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Newport Central',
#   'addr': u'former post office 99 High Street Newport Isle Of Wight PO301AB',
#   'commentsBy': u'Change of use from post office to restaurant installation of extraction/ventilation equipment',
#   'easting': 449720.7,
#   'lat': 50.69985937298164,
#   'lon': -1.2973343850071557,
#   'northing': 89148.3,
#   'ref': u'TCP/27885/E - P/00478/15',
#   'stub': 'AppDetails3.aspx?frmId=29644'},
#  {u'Agent or Applicant': u'Ms K Priest Pegasus Planning Group Ltd\nFirst Floor South Wing Equinox North Great Park Road Almondsbury Bristol BS32 4QL',
#   u'Case Officer': u'Hayley Byrne',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'449720.7 / 89148.3',
#   u'Location': u'former post office 99 High Street Newport Isle Of Wight PO301AB',
#   u'Parish': u'Newport',
#   u'Proposal': u'Minor Commercial (Shop Front) Application Alterations to form new shop front alterations to rear elevation including provision of external seating area',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Newport Central',
#   'addr': u'former post office 99 High Street Newport Isle Of Wight PO301AB',
#   'commentsBy': u'Minor Commercial (Shop Front) Application  Alterations to form new shop front alterations to rear elevation including provision of external seating area',
#   'easting': 449720.7,
#   'lat': 50.69985937298164,
#   'lon': -1.2973343850071557,
#   'northing': 89148.3,
#   'ref': u'TCP/27885/D - P/00490/15',
#   'stub': 'AppDetails3.aspx?frmId=29645'},
#  {u'Agent or Applicant': u'Ms K Priest Pegasus Planning Group Ltd\nFirst Floor South Wing Equinox North Great Park Road Almondsbury Bristol BS32 4QL',
#   u'Case Officer': u'Hayley Byrne',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'449720.7 / 89148.3',
#   u'Location': u'former post office 99 High Street Newport Isle Of Wight PO301AB',
#   u'Parish': u'Newport',
#   u'Proposal': u'LBC for demolition of outbuildings and internal and external alterations in connection with change of use from post office to restaurant to include installation of extraction/ventilation equipment new shop front and alterations to rear elevation including provision of external seating area',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Newport Central',
#   'addr': u'former post office 99 High Street Newport Isle Of Wight PO301AB',
#   'commentsBy': u'LBC for demolition of outbuildings and internal and external alterations in connection with change of use from post office to restaurant to include installation of extraction/ventilation equipment new shop front and alterations to rear elevation including provision of external seating area',
#   'easting': 449720.7,
#   'lat': 50.69985937298164,
#   'lon': -1.2973343850071557,
#   'northing': 89148.3,
#   'ref': u'LBC/27885/F - P/00515/15',
#   'stub': 'AppDetails3.aspx?frmId=29646'},
#  {u'Agent or Applicant': u'Mr R Gray Robert Gray Design Ltd\n12 Donnington Drive Shanklin Isle of Wight PO37 7JA\n01983 865193',
#   u'Case Officer': u'Hayden Marsh',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'459736.5 / 84167.4',
#   u'Location': u'1618 Melville Street Sandown Isle Of Wight PO368JW',
#   u'Parish': u'Sandown',
#   u'Proposal': u'Alterations and change of use of ground floor restaurant to form a flat',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Sandown South',
#   'addr': u'1618 Melville Street Sandown Isle Of Wight PO368JW',
#   'commentsBy': u'Alterations and change of use of ground floor restaurant to form a flat',
#   'easting': 459736.5,
#   'lat': 50.65413163238003,
#   'lon': -1.1563319420717564,
#   'northing': 84167.4,
#   'ref': u'TCP/18480/G - P/00278/15',
#   'stub': 'AppDetails3.aspx?frmId=29648'},
#  {u'Agent or Applicant': u'Mr J Sackett Apple Panels\nBuilding 397 Aviation Business Park Bournemouth Int Airport Christchurch Dorset BH23 6NW',
#   u'Case Officer': u'Sarah Gooch',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'455670.0 / 77653.3',
#   u'Location': u'54 Ocean View Road Ventnor Isle Of Wight PO381AB',
#   u'Parish': u'Ventnor',
#   u'Proposal': u'Householder Application Proposed conservatory',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'Ventnor West',
#   'addr': u'54 Ocean View Road Ventnor Isle Of Wight PO381AB',
#   'commentsBy': u'Householder Application  Proposed conservatory',
#   'easting': 455670.0,
#   'lat': 50.59595910429087,
#   'lon': -1.214826292205832,
#   'northing': 77653.3,
#   'ref': u'TCP/32264 - P/00507/15',
#   'stub': 'AppDetails3.aspx?frmId=29633'},
#  {u'Agent or Applicant': u'',
#   u'Case Officer': u'Sarah Gooch',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 05/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'435944.5 / 89645.4',
#   u'Location': u'12 The Mount Yarmouth Isle Of Wight PO410RB',
#   u'Parish': u'Yarmouth',
#   u'Proposal': u'Householder Application Demolition of balcony and conservatory replacement balcony replacement cladding',
#   u'Publicity Date': u'15/05/2015',
#   u'Ward': u'West Wight',
#   'addr': u'12 The Mount Yarmouth Isle Of Wight PO410RB',
#   'commentsBy': u'Householder Application  Demolition of balcony and conservatory replacement balcony replacement cladding',
#   'easting': 435944.5,
#   'lat': 50.705341527943595,
#   'lon': -1.4923430359054086,
#   'northing': 89645.4,
#   'ref': u'TCP/32261 - P/00496/15',
#   'stub': 'AppDetails3.aspx?frmId=29635'},
#  {u'Agent or Applicant': u'Mr N White 36a West Street Ryde Isle of Wight PO33 2QF',
#   u'Case Officer': u'Hayden Marsh',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'456605.1 / 84170.9',
#   u'Location': u'Ruskin Alverstone Road Apse Heath Sandown Isle Of Wight PO360LE',
#   u'Parish': u'Newchurch',
#   u'Proposal': u'Householder Application Demolition of conservatory proposed single storey extension on rear elevation to form ensuite bedroom and enlarge kitchen with utility room',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Arreton and Newchurch',
#   'addr': u'Ruskin Alverstone Road Apse Heath Sandown Isle Of Wight PO360LE',
#   'commentsBy': u'Householder Application  Demolition of conservatory proposed single storey extension on rear elevation to form ensuite bedroom and enlarge kitchen with utility room',
#   'easting': 456605.1,
#   'lat': 50.65447523824982,
#   'lon': -1.2006233484708144,
#   'northing': 84170.9,
#   'ref': u'TCP/32256 - P/00479/15',
#   'stub': 'AppDetails3.aspx?frmId=29618'},
#  {u'Agent or Applicant': u'Miss R Mahendran MG Architects\n2 Northfields Prospect Northfields London SW18 1PE',
#   u'Case Officer': u'Hayden Marsh',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'464148.7 / 87932.9',
#   u'Location': u'88 High Street Bembridge Isle Of Wight PO355SF',
#   u'Parish': u'Bembridge',
#   u'Proposal': u'Householder Application Proposed single storey extension on front elevation to enlarge kitchen',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Brading St Helens and Bembridge',
#   'addr': u'88 High Street Bembridge Isle Of Wight PO355SF',
#   'commentsBy': u'Householder Application  Proposed single storey extension on front elevation to enlarge kitchen',
#   'easting': 464148.7,
#   'lat': 50.68752121719055,
#   'lon': -1.0932733545519746,
#   'northing': 87932.9,
#   'ref': u'TCP/04935/G - P/00474/15',
#   'stub': 'AppDetails3.aspx?frmId=29603'},
#  {u'Agent or Applicant': u'Mr J Gosling J P Designs\nSunny Heights Arnold Road Binstead Ryde Isle of Wight PO33 3RG\n01983 616768',
#   u'Case Officer': u'Sarah Gooch',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'460638.3 / 87258.3',
#   u'Location': u'Kyngs Gift Shop and Tearoom High Street Brading Sandown Isle Of Wight PO36 0DQ',
#   u'Parish': u'Brading',
#   u'Proposal': u'Alterations replacement of flat roof to single storey element with pitched replacement flat roof to rear proposed bollards to front pavement area',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Brading St Helens and Bembridge',
#   'addr': u'Kyngs Gift Shop and Tearoom High Street Brading Sandown Isle Of Wight PO36 0DQ',
#   'commentsBy': u'Alterations replacement of flat roof to single storey element with pitched replacement flat roof to rear proposed bollards to front pavement area',
#   'easting': 460638.3,
#   'lat': 50.68183120930284,
#   'lon': -1.1430709918571467,
#   'northing': 87258.3,
#   'ref': u'TCP/22055/W - P/00435/15',
#   'stub': 'AppDetails3.aspx?frmId=29604'},
#  {u'Agent or Applicant': u'Mrs C Howlett Hepburns Planning Consultancy Ltd\nCheeks Farm Merstone Lane Merstone Newport Isle of Wight PO30 3DE\n522100',
#   u'Case Officer': u'Richard Holmes',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'442617.4 / 81984.3',
#   u'Location': u'Barn adjacent to 1 and 2 Marsh Green Cottages Marsh Green Brighstone Newport Isle Of Wight PO30',
#   u'Parish': u'Brighstone',
#   u'Proposal': u'Variation of condition no. 3 and removal of conditions nos. 4 and 5 on P/00581/14 TCP/31481/A to allow the approved holiday accommodation to be used as a dwelling',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Central Wight',
#   'addr': u'Barn adjacent to 1 and 2 Marsh Green Cottages Marsh Green Brighstone Newport Isle Of Wight PO30',
#   'commentsBy': u'Variation of condition no. 3 and removal of conditions nos. 4 and 5 on P/00581/14  TCP/31481/A to allow the approved holiday accommodation to be used as a dwelling',
#   'easting': 442617.4,
#   'lat': 50.6360014457109,
#   'lon': -1.398731457416921,
#   'northing': 81984.3,
#   'ref': u'TCP/31481/B - P/00481/15',
#   'stub': 'AppDetails3.aspx?frmId=29605'},
#  {u'Agent or Applicant': u'C A Fairweather A.I.P.D\nKingfishers 36A Merrie Gardens Sandown Isle of Wight PO36 9QN',
#   u'Case Officer': u'Richard Holmes',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'451109.4 / 83982.2',
#   u'Location': u'Ward Erectors Pritchetts Way Rookley Ventnor Isle Of Wight PO38',
#   u'Parish': u'Rookley',
#   u'Proposal': u'Change of use of former steel fabricators to car sales car maintenance and MOT facilities',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Central Wight',
#   'addr': u'Ward Erectors Pritchetts Way Rookley Ventnor Isle Of Wight PO38',
#   'commentsBy': u'Change of use of former steel fabricators to car sales car maintenance and MOT facilities',
#   'easting': 451109.4,
#   'lat': 50.65328554924688,
#   'lon': -1.2783848805113625,
#   'northing': 83982.2,
#   'ref': u'TCP/32255 - P/00473/15',
#   'stub': 'AppDetails3.aspx?frmId=29629'},
#  {u'Agent or Applicant': u'Mr J Sackett Apple Panels\nBuilding 397 Aviation Business Park Bournemouth Int Airport Christchurch Dorset BH23 6NW',
#   u'Case Officer': u'Sarah Gooch',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'450577.9 / 76713.0',
#   u'Location': u'Kelowna Cottage Blackgang Road Niton Ventnor Isle Of Wight PO382BN',
#   u'Parish': u'Niton and Whitwell',
#   u'Proposal': u'Householder Application Conservatory',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Chale Niton and Whitwell',
#   'addr': u'Kelowna Cottage Blackgang Road Niton Ventnor Isle Of Wight PO382BN',
#   'commentsBy': u'Householder Application  Conservatory',
#   'easting': 450577.9,
#   'lat': 50.58796626550948,
#   'lon': -1.2868915158769925,
#   'northing': 76713.0,
#   'ref': u'TCP/32100/A - P/00487/15',
#   'stub': 'AppDetails3.aspx?frmId=29628'},
#  {u'Agent or Applicant': u'Mr C Blenkinsop 6 Marsh Road Cowes Isle Of Wight PO318JQ',
#   u'Case Officer': u'Hayley Byrne',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'447166.7 / 95312.0',
#   u'Location': u'8 Marsh Road Cowes Isle Of Wight PO318JQ',
#   u'Parish': u'Gurnard',
#   u'Proposal': u'Householder Application Proposed summer house',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Cowes West and Gurnard',
#   'addr': u'8 Marsh Road Cowes Isle Of Wight PO318JQ',
#   'commentsBy': u'Householder Application  Proposed summer house',
#   'easting': 447166.7,
#   'lat': 50.755495940135056,
#   'lon': -1.3327089887818602,
#   'northing': 95312.0,
#   'ref': u'TCP/19157/D - P/00428/15',
#   'stub': 'AppDetails3.aspx?frmId=29609'},
#  {u'Agent or Applicant': u'Mr P Salmon Phil Salmon Planning Ltd\n143 Staplers Road Newport Isle of Wight PO30 2DJ',
#   u'Case Officer': u'Richard Holmes',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'434033.2 / 88173.7',
#   u'Location': u'Mountfield Holiday Park Norton Green Freshwater Isle Of Wight PO409RU',
#   u'Parish': u'Freshwater',
#   u'Proposal': u'Variation of condition no. 2 on TCP/3664/L/RD to enable design revision to 46 approved holiday units',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Freshwater North',
#   'addr': u'Mountfield Holiday Park Norton Green Freshwater Isle Of Wight PO409RU',
#   'commentsBy': u'Variation of condition no. 2 on TCP/3664/L/RD to enable design revision to 46 approved holiday units',
#   'easting': 434033.2,
#   'lat': 50.692222081929266,
#   'lon': -1.5195436452773516,
#   'northing': 88173.7,
#   'ref': u'TCP/32257 - P/00450/15',
#   'stub': 'AppDetails3.aspx?frmId=29606'},
#  {u'Agent or Applicant': u'Mr T Stocker Turley\n6th Floor North 2 Charlotte Place Southampton Hampshire SO14 0TB',
#   u'Case Officer': u'Mike Gildersleeves',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'434326.3 / 87044.3',
#   u'Location': u'CoOp Store Hooke Hill Freshwater Isle Of Wight PO409LD',
#   u'Parish': u'Freshwater',
#   u'Proposal': u'Demolition of building outline for residential development of 9 houses and 11 flats with associated parking and formation of vehicular accesses',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Freshwater South',
#   'addr': u'CoOp Store Hooke Hill Freshwater Isle Of Wight PO409LD',
#   'commentsBy': u'Demolition of building outline for residential development of 9 houses and 11 flats with associated parking and formation of vehicular accesses',
#   'easting': 434326.3,
#   'lat': 50.682048898635514,
#   'lon': -1.5154988347423128,
#   'northing': 87044.3,
#   'ref': u'TCP/30416/A - P/00476/15',
#   'stub': 'AppDetails3.aspx?frmId=29607'},
#  {u'Agent or Applicant': u'Mr S Holbrook Holbrook Architectural Sevices Ltd\n3 Windmill Close Haylands Ryde Isle of Wight PO33 3JB',
#   u'Case Officer': u'Sarah Gooch',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'452612.2 / 81087.4',
#   u'Location': u'Plum Tree Cottage Sheepwash Lane Godshill Ventnor Isle Of Wight PO383JS',
#   u'Parish': u'Godshill',
#   u'Proposal': u'Householder Application Proposed single storey extension to form porch proposed detached outbuilding to form garage/carport',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Godshill and Wroxall',
#   'addr': u'Plum Tree Cottage Sheepwash Lane Godshill Ventnor Isle Of Wight PO383JS',
#   'commentsBy': u'Householder Application  Proposed single storey extension to form porch proposed detached outbuilding to form garage/carport',
#   'easting': 452612.2,
#   'lat': 50.62712188159479,
#   'lon': -1.2575387368769988,
#   'northing': 81087.4,
#   'ref': u'TCP/32258 - P/00458/15',
#   'stub': 'AppDetails3.aspx?frmId=29608'},
#  {u'Agent or Applicant': u'Mr S Pelly Simpson and Allinson Litd.\nHarmire Enterprise Park Barnard Castle County Durham DL12 8EH',
#   u'Case Officer': u'Richard Holmes',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'455305.6 / 81351.9',
#   u'Location': u'Upper Winstone Farm St. Johns Road Wroxall Ventnor Isle Of Wight PO383AA',
#   u'Parish': u'Wroxall',
#   u'Proposal': u'Proposed roundhouse livestock building',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Godshill and Wroxall',
#   'addr': u'Upper Winstone Farm St. Johns Road Wroxall Ventnor Isle Of Wight PO383AA',
#   'commentsBy': u'Proposed roundhouse livestock building',
#   'easting': 455305.6,
#   'lat': 50.629251502085474,
#   'lon': -1.2194242046079495,
#   'northing': 81351.9,
#   'ref': u'TCP/18511/L - P/00437/15',
#   'stub': 'AppDetails3.aspx?frmId=29617'},
#  {u'Agent or Applicant': u'Mr T Howell THA Studio\n136 Binstead Lodge Road Ryde Isle of Wight PO33 3UP',
#   u'Case Officer': u'Hayden Marsh',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'458783.3 / 91544.1',
#   u'Location': u'6 Pitt Street Ryde Isle Of Wight PO333EB',
#   u'Parish': u'Ryde',
#   u'Proposal': u'Householder Application Demolition of single storey extension proposed two storey extension on side elevation to form additional living accommodation',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Havenstreet Ashey and Haylands',
#   'addr': u'6 Pitt Street Ryde Isle Of Wight PO333EB',
#   'commentsBy': u'Householder Application  Demolition of single storey extension proposed two storey extension on side elevation to form additional living accommodation',
#   'easting': 458783.3,
#   'lat': 50.72055806269134,
#   'lon': -1.1686433107139058,
#   'northing': 91544.1,
#   'ref': u'TCP/19297/A - P/00459/15',
#   'stub': 'AppDetails3.aspx?frmId=29630'},
#  {u'Agent or Applicant': u'Mr T Howell Mitchell Evans LLP\nBaring Chambers Denmark Road Cowes Isle of Wight PO31 7SY',
#   u'Case Officer': u'Stuart VanCuylenburg',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'449823.0 / 89340.3',
#   u'Location': u'Wessex Youth Offending Team 62 Crocker Street Newport Isle Of Wight PO305DA',
#   u'Parish': u'Newport',
#   u'Proposal': u'Change of use from office accommodation to a dwelling including internal and external alterations including new wrought iron railing to front elevation',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Newport Central',
#   'addr': u'Wessex Youth Offending Team 62 Crocker Street Newport Isle Of Wight PO305DA',
#   'commentsBy': u'Change of use from office accommodation to a dwelling including internal and external alterations including new wrought iron railing to front elevation',
#   'easting': 449823.0,
#   'lat': 50.70157710512265,
#   'lon': -1.295860121639297,
#   'northing': 89340.3,
#   'ref': u'TCPL/04275/P - P/00383/15',
#   'stub': 'AppDetails3.aspx?frmId=29619'},
#  {u'Agent or Applicant': u'Mr T Howell Mitchell Evans LLP\nBaring Chambers Denmark Road Cowes Isle of Wight PO31 7SY',
#   u'Case Officer': u'Stuart VanCuylenburg',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'449823.0 / 89340.3',
#   u'Location': u'Wessex Youth Offending Team 62 Crocker Street Newport Isle Of Wight PO305DA',
#   u'Parish': u'Newport',
#   u'Proposal': u'LBC for change of use from office accommodation to a dwelling including internal and external alterations including new wrought iron railing to front elevation',
#   u'Publicity Date': u'08/05/2015',
#   u'Ward': u'Newport Central',
#   'addr': u'Wessex Youth Offending Team 62 Crocker Street Newport Isle Of Wight PO305DA',
#   'commentsBy': u'LBC for change of use from office accommodation to a dwelling including internal and external alterations including new wrought iron railing to front elevation',
#   'easting': 449823.0,
#   'lat': 50.70157710512265,
#   'lon': -1.295860121639297,
#   'northing': 89340.3,
#   'ref': u'LBC/04275/N - P/00384/15',
#   'stub': 'AppDetails3.aspx?frmId=29620'},
# ...
#   'addr': u'Ground Floor Apartment Sandcove Pier Road Seaview Isle Of Wight PO345BL',
#   'commentsBy': u'Householder Application  Alterations single storey extensions on east and north elevations to provide additional living accommodation',
#   'easting': 463060.3,
#   'lat': 50.718264519476705,
#   'lon': -1.1080981477536829,
#   'northing': 91338.8,
#   'ref': u'TCP/02103/P - P/00403/15',
#   'stub': 'AppDetails3.aspx?frmId=29576'},
#  {u'Agent or Applicant': u'Mrs M James Plan Research\nPo Box 37 Freshwater Isle of Wight PO40 9ZR',
#   u'Case Officer': u'Richard Holmes',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 15/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'462096.1 / 91892.9',
#   u'Location': u'Isle Of Wight Self Catering Ltd Salterns Road Seaview Isle Of Wight PO345AQ',
#   u'Parish': u'Nettlestone and Seaview',
#   u'Proposal': u'Advertisement Consent Application 2 x flag poles and flags',
#   u'Publicity Date': u'24/04/2015',
#   u'Ward': u'Nettlestone and Seaview',
#   'addr': u'Isle Of Wight Self Catering Ltd Salterns Road Seaview Isle Of Wight PO345AQ',
#   'commentsBy': u'Advertisement Consent Application  2 x flag poles and flags',
#   'easting': 462096.1,
#   'lat': 50.72335041286666,
#   'lon': -1.121661471180251,
#   'northing': 91892.9,
#   'ref': u'A/01155/B - P/00427/15',
#   'stub': 'AppDetails3.aspx?frmId=29577'},
#  {u'Agent or Applicant': u'Mr J Roper Easton Bevins\n436 440 Gloucester Road Bristol BS7 8TX',
#   u'Case Officer': u'Stuart VanCuylenburg',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 15/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'449815.2 / 89116.2',
#   u'Location': u'53 High Street Newport Isle Of Wight PO301SB',
#   u'Parish': u'Newport',
#   u'Proposal': u'Advertisement Consent Application 2 illuminated digital flank box signs',
#   u'Publicity Date': u'24/04/2015',
#   u'Ward': u'Newport Central',
#   'addr': u'53 High Street Newport Isle Of Wight PO301SB',
#   'commentsBy': u'Advertisement Consent Application  2 illuminated digital flank box signs',
#   'easting': 449815.2,
#   'lat': 50.69956265969652,
#   'lon': -1.2960007225245884,
#   'northing': 89116.2,
#   'ref': u'A/01585/C - P/00438/15',
#   'stub': 'AppDetails3.aspx?frmId=29581'},
#  {u'Agent or Applicant': u'Mr J Williams Kember Loudon Williams LLP\nRidgers Barn Bunny Lane Eridge Nr Tunbridge Wells Kent TN3 9HA\n01892750018',
#   u'Case Officer': u'Stuart VanCuylenburg',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 15/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'460074.1 / 92558.3',
#   u'Location': u'memorial gardens adjacent to 29 The Strand Ryde Isle Of Wight PO33',
#   u'Parish': u'Ryde',
#   u'Proposal': u'Proposed ventilation column',
#   u'Publicity Date': u'24/04/2015',
#   u'Ward': u'Ryde North East',
#   'addr': u'memorial gardens adjacent to 29 The Strand Ryde Isle Of Wight PO33',
#   'commentsBy': u'Proposed ventilation column',
#   'easting': 460074.1,
#   'lat': 50.729545657187835,
#   'lon': -1.150195130299069,
#   'northing': 92558.3,
#   'ref': u'TCP/32242 - P/00422/15',
#   'stub': 'AppDetails3.aspx?frmId=29565'},
#  {u'Agent or Applicant': u'Mr A Morgan Churchers Bolitho Way Solicitors\n13 Union Street Ryde Isle of Wight PO33 2DU',
#   u'Case Officer': u'Hayden Marsh',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 15/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'459281.6 / 92798.3',
#   u'Location': u'13a Union Street Ryde Isle Of Wight PO332DU',
#   u'Parish': u'Ryde',
#   u'Proposal': u'Change of use of 2nd floor flat to form additional office accommodation',
#   u'Publicity Date': u'24/04/2015',
#   u'Ward': u'Ryde North West',
#   'addr': u'13a Union Street Ryde Isle Of Wight PO332DU',
#   'commentsBy': u'Change of use of 2nd floor flat to form additional office accommodation',
#   'easting': 459281.6,
#   'lat': 50.73178492516649,
#   'lon': -1.1613839857895203,
#   'northing': 92798.3,
#   'ref': u'TCP/16235/M - P/00262/15',
#   'stub': 'AppDetails3.aspx?frmId=29566'},
#  {u'Agent or Applicant': u'Andrew E Hitt\nCorner House 68/70 Lugley Street Newport Isle of Wight PO30 5ET\n01983 528283',
#   u'Case Officer': u'Hayden Marsh',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 15/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'460128.1 / 84525.8',
#   u'Location': u'17 Avenue Road Sandown Isle Of Wight PO368BN',
#   u'Parish': u'Sandown',
#   u'Proposal': u'Alterations and two storey extension on south elevation to form one additional flat to the approved scheme under P/01457/13 for 5 flats',
#   u'Publicity Date': u'24/04/2015',
#   u'Ward': u'Sandown North',
#   'addr': u'17 Avenue Road Sandown Isle Of Wight PO368BN',
#   'commentsBy': u'Alterations and two storey extension on south elevation to form one additional flat to the approved scheme under P/01457/13 for 5 flats',
#   'easting': 460128.1,
#   'lat': 50.6573140690564,
#   'lon': -1.1507349351953378,
#   'northing': 84525.8,
#   'ref': u'TCP/13106/D - P/00433/15',
#   'stub': 'AppDetails3.aspx?frmId=29567'},
#  {u'Agent or Applicant': u'Mrs S Atkinson Rainey Petrie Architecture Ltd\nEast Quay Kite Hill Wootton Bridge Ryde Isle of Wight PO33 4LA',
#   u'Case Officer': u'Sarah Wilkinson',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 15/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'450681.4 / 93932.5',
#   u'Location': u'land west of Gustar Grove/Captains Parade/Abbey Walk off Saunders Way East Cowes PO32',
#   u'Parish': u'East Cowes',
#   u'Proposal': u'Approval of reserved matters for the appearance and landscaping of the dwelling and garage for plot 15 following outline consent ref TCP/18291/V P/01044/13',
#   u'Publicity Date': u'24/04/2015',
#   u'Ward': u'Whippingham and Osborne',
#   'addr': u'land west of Gustar Grove/Captains Parade/Abbey Walk off Saunders Way East Cowes PO32',
#   'commentsBy': u'Approval of reserved matters for the appearance and landscaping of the dwelling and garage for plot 15 following outline consent ref TCP/18291/V  P/01044/13',
#   'easting': 450681.4,
#   'lat': 50.74279598559256,
#   'lon': -1.2830764317446512,
#   'northing': 93932.5,
#   'ref': u'TCP/32222/A - P/00357/15',
#   'stub': 'AppDetails3.aspx?frmId=29572'},
#  {u'Agent or Applicant': u'',
#   u'Case Officer': u'Hayley Byrne',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 15/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'453384.8 / 91833.7',
#   u'Location': u'41 Lushington Hill Wootton Bridge Ryde Isle Of Wight PO334NT',
#   u'Parish': u'Wootton Bridge',
#   u'Proposal': u'Proposed change of use alterations and single storey extension to convert former cattery building into self contained unit of holiday accommodation (revised description) (readvertised application)',
#   u'Publicity Date': u'24/04/2015',
#   u'Ward': u'Wootton Bridge',
#   'addr': u'41 Lushington Hill Wootton Bridge Ryde Isle Of Wight PO334NT',
#   'commentsBy': u'Proposed change of use alterations and single storey extension to convert former cattery building into self contained unit of holiday accommodation (revised description) (readvertised application)',
#   'easting': 453384.8,
#   'lat': 50.72368211061505,
#   'lon': -1.2450689133926425,
#   'northing': 91833.7,
#   'ref': u'TCP/16561/K - P/00057/15',
#   'stub': 'AppDetails3.aspx?frmId=29568'},
#  {u'Agent or Applicant': u'Mr T Howell THA Studio\n136 Binstead Lodge Road Ryde Isle of Wight PO33 3UP',
#   u'Case Officer': u'Richard Holmes',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 02/06/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'461288.0 / 91609.0',
#   u'Location': u'The Coach House Woodlands Vale Calthorpe Road Ryde Isle Of Wight PO331PR',
#   u'Parish': u'Nettlestone and Seaview',
#   u'Proposal': u'Householder Application Proposed outbuilding to form garden room and office',
#   u'Publicity Date': u'17/04/2015',
#   u'Ward': u'Nettlestone and Seaview',
#   'addr': u'The Coach House Woodlands Vale Calthorpe Road Ryde Isle Of Wight PO331PR',
#   'commentsBy': u'Householder Application  Proposed outbuilding to form garden room and office',
#   'easting': 461288.0,
#   'lat': 50.720883331729986,
#   'lon': -1.133155341632476,
#   'northing': 91609.0,
#   'ref': u'TCP/25217/C - P/00389/15',
#   'stub': 'AppDetails3.aspx?frmId=29554'},
#  {u'Agent or Applicant': u'Mr R Holden Holden Harper\n26 High Street Wimbledon London SW19 5BY',
#   u'Case Officer': u'Stuart VanCuylenburg',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'449983.0 / 89360.0',
#   u'Location': u'12 Holyrood Street Newport Isle Of Wight PO30',
#   u'Parish': u'Newport',
#   u'Proposal': u'Alterations and three storey rear/side extension to No. 1 to provide 6 additional ensuite bedrooms dining facilities and covered bin store for existing guest house to include dormer windows on north and west elevations',
#   u'Publicity Date': u'30/01/2015',
#   u'Ward': u'Newport Central',
#   'addr': u'12 Holyrood Street Newport Isle Of Wight PO30',
#   'commentsBy': u'Alterations and three storey rear/side extension to No. 1 to provide 6 additional ensuite bedrooms dining facilities and covered bin store for existing guest house to include dormer windows on north and west elevations',
#   'easting': 449983.0,
#   'lat': 50.701740547496335,
#   'lon': -1.2935920125063018,
#   'northing': 89360.0,
#   'ref': u'TCPL/19778/K - P/00050/15',
#   'stub': 'AppDetails3.aspx?frmId=29224'},
#  {u'Agent or Applicant': u'Mr R Holden Holden Harper\n26 High Street Wimbledon London SW19 5BY',
#   u'Case Officer': u'Stuart VanCuylenburg',
#   u'Comments Date': u'Comments on this Application must be received by close of business on 29/05/2015\nAll Planning Applications are publicised by a variety of methods giving a period of 21 days for the submission of comments to the Planning Department. This is known as the consultation period. Comments received after this period has expired may be accepted and taken into account, providing they are relevant and material to the decision and if the application has not already been determined. Therefore, failure to submit representations within the consultation period may prejudice the chance of your comments being taken into account.',
#   u'Easting/Northing': u'449983.0 / 89360.0',
#   u'Location': u'12 Holyrood Street Newport Isle Of Wight PO30',
#   u'Parish': u'Newport',
#   u'Proposal': u'LBC for alterations and three storey rear/side extension to No. 1 to provide 6 additional ensuite bedrooms dining facilities and covered bin store for existing guest house to include dormer windows on north and west elevations',
#   u'Publicity Date': u'30/01/2015',
#   u'Ward': u'Newport Central',
#   'addr': u'12 Holyrood Street Newport Isle Of Wight PO30',
#   'commentsBy': u'LBC for alterations and three storey rear/side extension to No. 1 to provide 6 additional ensuite bedrooms dining facilities and covered bin store for existing guest house to include dormer windows on north and west elevations',
#   'easting': 449983.0,
#   'lat': 50.701740547496335,
#   'lon': -1.2935920125063018,
#   'northing': 89360.0,
#   'ref': u'LBC/19778/J - P/00051/15',
#   'stub': 'AppDetails3.aspx?frmId=29225'}]
